# %%
# %run generate_portfolio.py
# Out:
# HTML file generated successfully!

# %%
# %run generate_portfolio.py
# Out:
# HTML file generated successfully!

# %%
# %run generate_portfolio.py
# Out:
# HTML file generated successfully!

# %%
# %run generate_portfolio.py
# Out:
# HTML file generated successfully!

# %%
# %run generate_portfolio.py
# Out:
# HTML file generated successfully!

# %%
# %run generate_portfolio.py
# Out:
# HTML file generated successfully!
